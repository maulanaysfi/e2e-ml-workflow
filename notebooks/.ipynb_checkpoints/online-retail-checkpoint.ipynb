# %% [markdown]
# # Prerequisites
# Importing libraries and datasets.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

pd.set_option('display.float_format', '{:.2f}'.format)

# %%
home_dir = Path.home()
print(home_dir)
# Out:
# /home/ibrahim

# %%
df1 = pd.read_csv(f"{home_dir}/git_repos/kubeflow-e2e/datasets/online+retail+ii/online_retail_II.csv")
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  object
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.1+ MB

# %%
df2 = pd.read_csv(f"{home_dir}/git_repos/kubeflow-e2e/datasets/online+retail/online-retail.csv")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# # Data Preparation
# Combining two separated datasets into a single dataset.

# %% [markdown]
# ## Renaming columns

# %%
df1['UnitPrice'] = df1['Price']
df1['InvoiceNo'] = df1['Invoice']
df1['CustomerID'] = df1['Customer ID']
print(f'Columns: {df1.columns}')
df1 = df1.drop(columns=['Price', 'Invoice', 'Customer ID'])
print(f'Columns: {df1.columns}')
# Out:
# Columns: Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'UnitPrice', 'InvoiceNo',
#        'CustomerID'],
#       dtype='object')
# Columns: Index(['StockCode', 'Description', 'Quantity', 'InvoiceDate', 'Country',
#        'UnitPrice', 'InvoiceNo', 'CustomerID'],
#       dtype='object')

# %% [markdown]
# ## Changing column type

# %%
df1['InvoiceDate'] = pd.to_datetime(df1['InvoiceDate'])
df2['InvoiceDate'] = pd.to_datetime(df2['InvoiceDate'])

# %% [markdown]
# ## Setting merge point

# %%
print(f'End of First data: {df1['InvoiceDate'].max()}')
print(f'Start of Second data: {df2['InvoiceDate'].min()}')
# Out:
# End of First data: 2010-12-09 20:01:00
# Start of Second data: 2010-12-01 08:26:00

# %%
print(df1['InvoiceDate'].nunique())
print(df2['InvoiceDate'].nunique())
# Out:
# 25296
# 23260

# %%
df2 = df2[df2['InvoiceDate'] > df1['InvoiceDate'].max()]
print(df2['InvoiceDate'].nunique())
# Out:
# 22339

# %% [markdown]
# ## Merging data

# %%
df = pd.concat([df1, df2])
df = df.reset_index(drop=True)
df
# Out:
#         StockCode                          Description  Quantity  \
# 0           85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1          79323P                   PINK CHERRY LIGHTS        12
# 2          79323W                  WHITE CHERRY LIGHTS        12
# 3           22041         RECORD FRAME 7" SINGLE SIZE         48
# 4           21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...           ...                                  ...       ...
# 1044842     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 1044843     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1044844     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1044845     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1044846     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate         Country  UnitPrice InvoiceNo  CustomerID
# 0       2009-12-01 07:45:00  United Kingdom       6.95    489434    13085.00
# 1       2009-12-01 07:45:00  United Kingdom       6.75    489434    13085.00
# 2       2009-12-01 07:45:00  United Kingdom       6.75    489434    13085.00
# 3       2009-12-01 07:45:00  United Kingdom       2.10    489434    13085.00
# 4       2009-12-01 07:45:00  United Kingdom       1.25    489434    13085.00
# ...                     ...             ...        ...       ...         ...
# 1044842 2011-12-09 12:50:00          France       0.85    581587    12680.00
# 1044843 2011-12-09 12:50:00          France       2.10    581587    12680.00
# 1044844 2011-12-09 12:50:00          France       4.15    581587    12680.00
# 1044845 2011-12-09 12:50:00          France       4.15    581587    12680.00
# 1044846 2011-12-09 12:50:00          France       4.95    581587    12680.00
#
# [1044847 rows x 8 columns]

# %%
df.info()
df.reset_index(drop=True).to_csv(f'{home_dir}/git_repos/kubeflow-e2e/datasets/online-retail-full.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044847 entries, 0 to 1044846
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   StockCode    1044847 non-null  object
#  1   Description  1040572 non-null  object
#  2   Quantity     1044847 non-null  int64
#  3   InvoiceDate  1044847 non-null  datetime64[ns]
#  4   Country      1044847 non-null  object
#  5   UnitPrice    1044847 non-null  float64
#  6   InvoiceNo    1044847 non-null  object
#  7   CustomerID   809560 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 63.8+ MB

# %% [markdown]
# # Data Assessing, Cleaning and Transforming
# Checking data reliability, handling missing values and outliers.

# %%
df.describe()
# Out:
#         Quantity                    InvoiceDate  UnitPrice  CustomerID
# count 1044847.00                        1044847 1044847.00   809560.00
# mean        9.99  2011-01-03 11:43:47.797945856       4.59    15319.76
# min    -80995.00            2009-12-01 07:45:00  -53594.36    12346.00
# 25%         1.00            2010-07-05 11:11:00       1.25    13969.00
# 50%         3.00            2010-12-08 16:34:00       2.10    15248.00
# 75%        10.00            2011-07-27 13:42:00       4.13    16792.00
# max     80995.00            2011-12-09 12:50:00   38970.00    18287.00
# std       174.22                            NaN     121.70     1695.81

# %%
print(df.isna().sum())
# Out:
# StockCode           0
# Description      4275
# Quantity            0
# InvoiceDate         0
# Country             0
# UnitPrice           0
# InvoiceNo           0
# CustomerID     235287
# dtype: int64

# %% [markdown]
# ## Assessing NULL values

# %% [markdown]
# Assessing data with NULL CustomerID. Are the transactions valid?

# %%
df_customer_isna = df[df['CustomerID'].isna() == True]
df_customer_isna.reset_index(drop=True).to_csv(f'{home_dir}/git_repos/kubeflow-e2e/datasets/online-retail-nan-customerid.csv', index=False)

# %% [markdown]
# Assessing data with NULL Description. Are the transactions valid?

# %%
df_desc_isna = df[df['Description'].isna() == True]
df_desc_isna.reset_index(drop=True).to_csv(f'{home_dir}/git_repos/kubeflow-e2e/datasets/online-retail-nan-desc.csv', index=False)

# %%
# df = df.dropna(subset='Description')
print(df.isna().sum())
# Out:
# StockCode           0
# Description      4275
# Quantity            0
# InvoiceDate         0
# Country             0
# UnitPrice           0
# InvoiceNo           0
# CustomerID     235287
# dtype: int64

# %% [markdown]
# ## Datetime extraction
# Extracting Year, Month, Week, Single Date, Normalized Date, Day of week and Day name from datetime column.

# %%
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month
df['Week'] = df['InvoiceDate'].dt.isocalendar().week.astype(int)
df['Date'] = df['InvoiceDate'].dt.day
df['NormDate'] = df['InvoiceDate'].dt.normalize()

# 0=monday, 6=sunday
df['DayOfWeek'] = df['InvoiceDate'].dt.dayofweek
df['Day'] = df['InvoiceDate'].dt.day_name()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044847 entries, 0 to 1044846
# Data columns (total 15 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   StockCode    1044847 non-null  object
#  1   Description  1040572 non-null  object
#  2   Quantity     1044847 non-null  int64
#  3   InvoiceDate  1044847 non-null  datetime64[ns]
#  4   Country      1044847 non-null  object
#  5   UnitPrice    1044847 non-null  float64
#  6   InvoiceNo    1044847 non-null  object
#  7   CustomerID   809560 non-null   float64
#  8   Year         1044847 non-null  int32
#  9   Month        1044847 non-null  int32
#  10  Week         1044847 non-null  int64
#  11  Date         1044847 non-null  int32
#  12  NormDate     1044847 non-null  datetime64[ns]
#  13  DayOfWeek    1044847 non-null  int32
#  14  Day          1044847 non-null  object
# dtypes: datetime64[ns](2), float64(2), int32(4), int64(2), object(5)
# memory usage: 103.6+ MB

# %%
df['Year'].unique()
# Out:
# array([2009, 2010, 2011], dtype=int32)

# %% [markdown]
# ## Negative value (loss) handling

# %% [markdown]
# Some unit prices are invalid (zero or negative). To avoid invalid Sales value, these values are going to be deleted.

# %%
invalid_unitprice = df[df['UnitPrice'] <= 0]
print(f'Total rows with invalid unit price: {int(invalid_unitprice['UnitPrice'].count())}')
df = df[df['UnitPrice'] > 0]
print(f'Current minimal unit price value: {df['UnitPrice'].min()}')
# Out:
# Total rows with invalid unit price: 6029
# Current minimal unit price value: 0.001

# %% [markdown]
# Creating Sales value. Some quantity values are negative, but it does not mean that they were invalid. They indicates losses.

# %%
df['Sales'] = df['Quantity'] * df['UnitPrice']
# Out:
# /tmp/ipykernel_203370/3178550718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sales'] = df['Quantity'] * df['UnitPrice']

# %%
print(df[df['Sales'] <= 0]['InvoiceNo'].count())
df = df[df['Sales'] > 0]
# Out:
# 19164

# %% [markdown]
# Calculating losses by summing both negative and positive quantities in every transaction (single same invoice).

# %%
df_unique_invoice = df.groupby('InvoiceNo').agg(
    ItemSold = ('InvoiceNo', 'count'),
    NormDate = ('NormDate', 'mean'),
    Year = ('Year', 'mean'),
    Month = ('Month', 'mean'),
    Week = ('Week', 'mean'),
    Date = ('Date', 'mean'),
    Quantity = ('Quantity', 'sum'),
    TotalSales = ('Sales', 'sum')
).sort_values('InvoiceNo', ascending=True).reset_index()

df_unique_invoice['Year'] = df_unique_invoice['Year'].astype('int64')
df_unique_invoice['Month'] = df_unique_invoice['Month'].astype('int64')
df_unique_invoice['Week'] = df_unique_invoice['Week'].astype('int64')
df_unique_invoice['Date'] = df_unique_invoice['Date'].astype('int64')
df_unique_invoice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40078 entries, 0 to 40077
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   InvoiceNo   40078 non-null  object
#  1   ItemSold    40078 non-null  int64
#  2   NormDate    40078 non-null  datetime64[ns]
#  3   Year        40078 non-null  int64
#  4   Month       40078 non-null  int64
#  5   Week        40078 non-null  int64
#  6   Date        40078 non-null  int64
#  7   Quantity    40078 non-null  int64
#  8   TotalSales  40078 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(1)
# memory usage: 2.8+ MB

# %%
invalid_quantity = df_unique_invoice[df_unique_invoice['Quantity'] < 1]
print(f'Total rows with invalid quantity: {int(invalid_quantity['Quantity'].count())}')
df_unique_invoice = df_unique_invoice[df_unique_invoice['Quantity'] > 0]
print(f'Current minimal quantity value: {df_unique_invoice['Quantity'].min()}')
# Out:
# Total rows with invalid quantity: 0
# Current minimal quantity value: 1

# %%
df_unique_invoice
# Out:
#       InvoiceNo  ItemSold   NormDate  Year  Month  Week  Date  Quantity  \
# 0        489434         8 2009-12-01  2009     12    49     1       166
# 1        489435         4 2009-12-01  2009     12    49     1        60
# 2        489436        19 2009-12-01  2009     12    49     1       193
# 3        489437        23 2009-12-01  2009     12    49     1       145
# 4        489438        17 2009-12-01  2009     12    49     1       826
# ...         ...       ...        ...   ...    ...   ...   ...       ...
# 40073    581585        21 2011-12-09  2011     12    49     9       278
# 40074    581586         4 2011-12-09  2011     12    49     9        66
# 40075    581587        15 2011-12-09  2011     12    49     9       105
# 40076   A563185         1 2011-08-12  2011      8    32    12         1
# 40077   C496350         1 2010-02-01  2010      2     5     1         1
#
#        TotalSales
# 0          505.30
# 1          145.80
# 2          630.33
# 3          310.75
# 4         2286.24
# ...           ...
# 40073      329.05
# 40074      339.20
# 40075      249.45
# 40076    11062.06
# 40077      373.57
#
# [40078 rows x 9 columns]

# %% [markdown]
# # Exploratory Analysis
# Visualizing data, extracting insights and useful informations.

# %% [markdown]
# ## Single item sales
# Each line in data represents a single sold item. There could be multiple items sold in a single invoice. Analyzing items sold in the data.

# %%
df2009 = df_unique_invoice[df_unique_invoice['Year'] == 2009]
df2010 = df_unique_invoice[df_unique_invoice['Year'] == 2010]
df2011 = df_unique_invoice[df_unique_invoice['Year'] == 2011]

# %%
transactions_2010 = df2010.groupby('Month').agg(
    count = ('ItemSold', 'sum')
).sort_values('Month', ascending=True).reset_index()

transactions_2011 = df2011.groupby('Month').agg(
    count = ('ItemSold', 'sum')
).sort_values('Month', ascending=True).reset_index()

df_array = [transactions_2010, transactions_2011]
df_array_year = ['2010', '2011']

plt.figure(figsize=(14,4))
for i, data in enumerate(df_array):
    sns.lineplot(data=data, x='Month', y='count', label=f'{df_array_year[i]}')
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1.01, 1.02))
plt.title('Sold item count by Month (per items) over Years')
plt.grid(alpha=0.4)
plt.ylabel('Items')
plt.xticks(range(1,13,1))
plt.show()

# %%
transactions_2010 = df2010.groupby('Week').agg(
    count = ('ItemSold', 'sum')
).sort_values('Week', ascending=True).reset_index()

transactions_2011 = df2011.groupby('Week').agg(
    count = ('ItemSold', 'sum')
).sort_values('Week', ascending=True).reset_index()

df_array = [transactions_2010, transactions_2011]
df_array_year = ['2010', '2011']

plt.figure(figsize=(14,4))
for i, data in enumerate(df_array):
    sns.lineplot(data=data, x='Week', y='count', label=f'{df_array_year[i]}')
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1.01, 1.02))
plt.title('Sold item count by Week (per items) over Years')
plt.ylabel('Items')
plt.grid(alpha=0.4)
plt.xlabel('Week in a Year')
plt.xticks(range(1, 55, 5))
plt.show()

# %% [markdown]
# ## Quantity
# Analyzing quantities sold.

# %%
quantity_sum_2010 = df2010.groupby('Month').agg(
    y = ('Quantity', 'sum')
).sort_values('Month', ascending=True).reset_index()

quantity_sum_2011 = df2011.groupby('Month').agg(
    y = ('Quantity', 'sum')
).sort_values('Month', ascending=True).reset_index()

df_array = [quantity_sum_2010, quantity_sum_2011]
df_array_year = ['2010', '2011']

plt.figure(figsize=(14,4))
for i, data in enumerate(df_array):
    sns.lineplot(data=data, x='Month', y='y', label=f'{df_array_year[i]}')
plt.title('Quantity Sold by Month over Years')
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1.01, 1.02))
plt.grid(alpha=0.4)
plt.ylabel('Sum')
plt.xticks(range(1,13,1))
plt.show()

# %%
quantity_sum_2010 = df2010.groupby('Week').agg(
    y = ('Quantity', 'sum')
).sort_values('Week', ascending=True).reset_index()

quantity_sum_2011 = df2011.groupby('Week').agg(
    y = ('Quantity', 'sum')
).sort_values('Week', ascending=True).reset_index()

df_array = [quantity_sum_2010, quantity_sum_2011]
df_array_year = ['2010', '2011']

plt.figure(figsize=(14,4))
for i, data in enumerate(df_array):
    sns.lineplot(data=data, x='Week', y='y', label=f'{df_array_year[i]}')
plt.title('Quantity Sold by Week over Years')
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1.01, 1.02))
plt.grid(alpha=0.4)
plt.ylabel('Sum')
plt.xlabel('Week in a Year')
plt.xticks(range(1, 55, 5))
plt.show()

# %% [markdown]
# ## Transactions
# Analyzing transactions by identifying its unique value (InvoiceNo). Counting total and average of transactions.

# %%
transactions_year_sum = df_unique_invoice.groupby('Year').agg(
    y = ('InvoiceNo', 'count')
).sort_values('Year', ascending=True).reset_index()

plt.figure(figsize=(14,4))
sns.barplot(data=transactions_year_sum, x='Year', y='y')
plt.title('Transactions occured by Year')
plt.ylabel('Transactions')
plt.xlabel('Year')
plt.show()

# %%
df2009_ui = df_unique_invoice[df_unique_invoice['Year'] == 2009]
df2010_ui = df_unique_invoice[df_unique_invoice['Year'] == 2010]
df2011_ui = df_unique_invoice[df_unique_invoice['Year'] == 2011]

# %%
transactions_2010_ui = df2010_ui.groupby('Month').agg(
    count = ('InvoiceNo', 'count')
).sort_values('Month', ascending=True).reset_index()

transactions_2011_ui = df2011_ui.groupby('Month').agg(
    count = ('InvoiceNo', 'count')
).sort_values('Month', ascending=True).reset_index()

df_array = [transactions_2010_ui, transactions_2011_ui]
df_array_year = ['2010', '2011']

plt.figure(figsize=(14,4))
for i, data in enumerate(df_array):
    sns.lineplot(data=data, x='Month', y='count', label=f'{df_array_year[i]}')
plt.legend(title='year', loc='upper left', bbox_to_anchor=(1.01, 1.02))
plt.title('Transactions occured by Month over Years')
plt.ylabel('Transactions')
plt.xlabel('Number of Month in a Year')
plt.xticks(range(1,13,1))
plt.grid(alpha=0.4)
plt.show()

# %%
transactions_2010_ui = df2010_ui.groupby('Week').agg(
    count = ('InvoiceNo', 'count')
).sort_values('Week', ascending=True).reset_index()

transactions_2011_ui = df2011_ui.groupby('Week').agg(
    count = ('InvoiceNo', 'count')
).sort_values('Week', ascending=True).reset_index()

df_array = [transactions_2010_ui, transactions_2011_ui]
df_array_year = ['2010', '2011']

plt.figure(figsize=(14,4))
for i, data in enumerate(df_array):
    sns.lineplot(data=data, x='Week', y='count', label=f'{df_array_year[i]}')
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1.01, 1.02))
plt.title('Transactions occured by Week over Years')
plt.ylabel('Transactions')
plt.xlabel('Number of Week in a Year')
plt.xticks(range(1, 55, 5))
plt.grid(alpha=0.4)
plt.show()

# %%
df_counts = df_unique_invoice.groupby('NormDate')['InvoiceNo'].nunique().reset_index()
df_counts['Date'] = pd.to_datetime(df_counts['NormDate']).dt.day
avg_df_counts = df_counts.groupby('Date')['InvoiceNo'].mean().reset_index()

plt.figure(figsize=(16,4))
sns.lineplot(data=avg_df_counts, x='Date', y='InvoiceNo')
plt.title('Average Transaction occured everyday in every Month')
plt.ylabel('Transactions')
plt.ylim(50,100)
plt.xlim(0.5,31.5)
plt.xticks(avg_df_counts['Date'].unique())
plt.grid(alpha=0.3)
plt.show()

# %%
df_counts = df_unique_invoice.groupby('NormDate')['InvoiceNo'].nunique().reset_index()
df_counts['DayName'] = pd.to_datetime(df_counts['NormDate']).dt.day_name()
avg_df_counts = df_counts.groupby('DayName')['InvoiceNo'].mean().reset_index()

days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
avg_df_counts['DayName'] = pd.Categorical(avg_df_counts['DayName'], categories=days, ordered=True)
avg_df_counts = avg_df_counts.sort_values('DayName')

plt.figure(figsize=(16,4))
sns.barplot(data=avg_df_counts, x='DayName', y='InvoiceNo', zorder=2, width=0.6)
plt.title('Average Transaction occured everyday in every Week')
plt.ylabel('Transactions')
plt.xlabel('Day of Week')
plt.xticks(avg_df_counts['DayName'].unique())
plt.grid(alpha=0.6, axis='y', zorder=1)
plt.show()

# %% [markdown]
# ## Sales
# Sales are obtained from the total items sold. Unit price multiplied by quantity equals sales. Analying sales values.

# %%
transactions_year_sum = df_unique_invoice.groupby('Year').agg(
    y = ('TotalSales', 'sum')
).sort_values('Year', ascending=True).reset_index()

plt.figure(figsize=(14,4))
sns.barplot(data=transactions_year_sum, x='Year', y='y')
plt.title('Total sales revenue obtained by Year')
plt.ylabel('Sterling')
plt.xlabel('Year')
plt.show()

# %%
transactions_2010_ui = df2010_ui.groupby('Month').agg(
    sum_sales = ('TotalSales', 'sum')
).sort_values('Month', ascending=True).reset_index()

transactions_2011_ui = df2011_ui.groupby('Month').agg(
    sum_sales = ('TotalSales', 'sum')
).sort_values('Month', ascending=True).reset_index()

df_array = [transactions_2010_ui, transactions_2011_ui]
df_array_year = ['2010', '2011']

plt.figure(figsize=(14,4))
for i, data in enumerate(df_array):
    sns.lineplot(data=data, x='Month', y='sum_sales', label=f'{df_array_year[i]}')
plt.legend(title='year', loc='upper left', bbox_to_anchor=(1.01, 1.02))
plt.title('Total sales revenue obtained by Month over Years')
plt.ylabel('Sterling')
plt.xlabel('Number of Month in a Year')
plt.xticks(range(1,13,1))
plt.grid(alpha=0.4)
plt.show()

# %%
transactions_2010_ui = df2010_ui.groupby('Week').agg(
    count = ('TotalSales', 'sum')
).sort_values('Week', ascending=True).reset_index()

transactions_2011_ui = df2011_ui.groupby('Week').agg(
    count = ('TotalSales', 'sum')
).sort_values('Week', ascending=True).reset_index()

df_array = [transactions_2010_ui, transactions_2011_ui]
df_array_year = ['2010', '2011']

plt.figure(figsize=(14,4))
for i, data in enumerate(df_array):
    sns.lineplot(data=data, x='Week', y='count', label=f'{df_array_year[i]}')
plt.legend(title='Year', loc='upper left', bbox_to_anchor=(1.01, 1.02))
plt.title('Total sales revenue obtained by Week over Years')
plt.ylabel('Sterling')
plt.xlabel('Number of Week in a Year')
plt.xticks(range(1, 55, 5))
plt.grid(alpha=0.4)
plt.show()

# %%
df_sales_sum = df_unique_invoice.groupby('NormDate')['TotalSales'].sum().reset_index()
df_sales_sum['Date'] = pd.to_datetime(df_sales_sum['NormDate']).dt.day
df_sales_sum
avg_sum_sales = df_sales_sum.groupby('Date')['TotalSales'].mean().reset_index()

plt.figure(figsize=(16,4))
sns.lineplot(data=avg_sum_sales, x='Date', y='TotalSales')
plt.title('Average Total sales revenue everyday in every Month')
plt.ylabel('Transactions')
# plt.ylim(50,100)
# plt.xlim(0.5,31.5)
plt.xticks(avg_sum_sales['Date'].unique())
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# # Feature Engineering
# Creating new column as feature.
#
# - Lag features (`lag_1`, `lag_7`, `lag_30`)
# - Rolling features (`rolling_mean_7`, `rolling_mean_30`, etc.)
# - EMA features
# - Price delta, discount flag
# - Seasonal (Start of month/End of month)

# %%
# Out:
# 0         505.30
# 1         145.80
# 2         630.33
# 3         310.75
# 4        2286.24
#           ...
# 40073     329.05
# 40074     339.20
# 40075     249.45
# 40076   11062.06
# 40077     373.57
# Name: TotalSales, Length: 40078, dtype: float64

# %% [markdown]
# ## Aggregated Historical Features
# - Lag 1, 7, 30
